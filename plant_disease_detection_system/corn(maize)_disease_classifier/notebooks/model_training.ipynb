# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers, models, callbacks
# Out:
# 2025-11-03 22:09:28.832581: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-03 22:09:28.862949: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-03 22:09:29.754721: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        for g in gpus:
            tf.config.experimental.set_memory_growth(g, True)
        print("Enabled memory growth for GPUs")
    except Exception as e:
        print("Could not set memory growth:", e)
# Out:
# Enabled memory growth for GPUs

# %%
BASE_DIR = "/home/amit/code_only/code/new/corn(maize)_disease_classifier/data"
IMAGE_SIZE = (256, 256)
BATCH_SIZE = 18
CHANNELS = 3
NUM_CLASSES = 4
EPOCHS = 50
AUTOTUNE = tf.data.AUTOTUNE

# %%
train_dir = os.path.join(BASE_DIR, "Train")
val_dir   = os.path.join(BASE_DIR, "Val")
test_dir  = os.path.join(BASE_DIR, "Test")

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    train_dir,
    labels="inferred",
    label_mode="int",
    image_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    shuffle=True,
    seed=123
)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    val_dir,
    labels="inferred",
    label_mode="int",
    image_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    shuffle=True,
    seed=123
)

test_ds = tf.keras.preprocessing.image_dataset_from_directory(
    test_dir,
    labels="inferred",
    label_mode="int",
    image_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    shuffle=False
)

class_names = train_ds.class_names
print("Classes:", class_names)
# Out:
# Found 7316 files belonging to 4 classes.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1762187971.905760   70704 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 6292 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.9
# Found 1645 files belonging to 4 classes.
# Found 206 files belonging to 5 classes.
# Classes: ['Cercospora Leaf Spot', 'Common Rust ', 'Healthy', 'Northern Leaf Blight']

# %%
train_ds = train_ds.shuffle(buffer_size=2000).prefetch(buffer_size=1)
val_ds   = val_ds.prefetch(buffer_size=1)
test_ds  = test_ds.prefetch(buffer_size=1)

# %%
AUTOTUNE = tf.data.AUTOTUNE
def augment(x, y):
    return x, y

# %%
input_shape = IMAGE_SIZE + (CHANNELS,)

augmentation = tf.keras.Sequential([
    layers.RandomFlip("horizontal_and_vertical"),
    layers.RandomRotation(0.10),
    layers.RandomZoom(0.1),
    layers.RandomContrast(0.1),
], name="augmentation")

model = models.Sequential([
    layers.Input(shape=input_shape),
    augmentation,
    layers.Rescaling(1./255),

    layers.Conv2D(32, 3, activation='relu', padding='same'),
    layers.BatchNormalization(),
    layers.MaxPooling2D(2),

    layers.Conv2D(64, 3, activation='relu', padding='same'),
    layers.BatchNormalization(),
    layers.MaxPooling2D(2),

    layers.Conv2D(128, 3, activation='relu', padding='same'),
    layers.BatchNormalization(),
    layers.MaxPooling2D(2),

    layers.Conv2D(128, 3, activation='relu', padding='same'),
    layers.BatchNormalization(),
    layers.MaxPooling2D(2),

    layers.GlobalAveragePooling2D(),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(NUM_CLASSES, activation='softmax')
], name="apple_disease_cnn")

model.compile(
    optimizer=tf.keras.optimizers.Adam(),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
    metrics=['accuracy']
)

model.summary()
# Out:
# Model: "apple_disease_cnn"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ augmentation (Sequential)       │ (None, 256, 256, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ rescaling (Rescaling)           │ (None, 256, 256, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 256, 256, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 256, 256, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 128, 128, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 128, 128, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 128, 128, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 64, 64, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 64, 64, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 64, 64, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 32, 32, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 32, 32, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 32, 32, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 16, 16, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 128)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 4)              │           516 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 259,268 (1012.77 KB)
#  Trainable params: 258,564 (1010.02 KB)
#  Non-trainable params: 704 (2.75 KB)

# %%
checkpoint_dir = "../models"
os.makedirs(checkpoint_dir, exist_ok=True)
checkpoint_path = os.path.join(checkpoint_dir, "best_model.keras")

cb = [
    callbacks.EarlyStopping(monitor='val_loss', patience=6, restore_best_weights=True),
    callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-6),
    callbacks.ModelCheckpoint(checkpoint_path, monitor='val_loss', save_best_only=True, verbose=1)
]

# %%
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS,
    callbacks=cb,
    verbose=1
)
# Out:
# Epoch 1/50
# 2025-11-03 22:09:37.205637: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:473] Loaded cuDNN version 91400
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.8341 - loss: 0.4360
# Epoch 1: val_loss improved from None to 2.07997, saving model to ../models/best_model.keras
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 37s 77ms/step - accuracy: 0.8824 - loss: 0.3175 - val_accuracy: 0.3647 - val_loss: 2.0800 - learning_rate: 0.0010
# Epoch 2/50
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.9296 - loss: 0.1904
# Epoch 2: val_loss improved from 2.07997 to 0.19299, saving model to ../models/best_model.keras
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 31s 76ms/step - accuracy: 0.9310 - loss: 0.1884 - val_accuracy: 0.9295 - val_loss: 0.1930 - learning_rate: 0.0010
# Epoch 3/50
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.9342 - loss: 0.1818
# Epoch 3: val_loss did not improve from 0.19299
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 31s 76ms/step - accuracy: 0.9393 - loss: 0.1699 - val_accuracy: 0.8912 - val_loss: 0.2677 - learning_rate: 0.0010
# Epoch 4/50
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.9523 - loss: 0.1385
# Epoch 4: val_loss did not improve from 0.19299
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 31s 76ms/step - accuracy: 0.9481 - loss: 0.1413 - val_accuracy: 0.7739 - val_loss: 0.7960 - learning_rate: 0.0010
# Epoch 5/50
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.9537 - loss: 0.1427
# Epoch 5: val_loss did not improve from 0.19299
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 31s 76ms/step - accuracy: 0.9533 - loss: 0.1328 - val_accuracy: 0.7696 - val_loss: 0.8199 - learning_rate: 0.0010
# Epoch 6/50
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.9701 - loss: 0.0893
# Epoch 6: val_loss improved from 0.19299 to 0.16338, saving model to ../models/best_model.keras
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 31s 76ms/step - accuracy: 0.9688 - loss: 0.0909 - val_accuracy: 0.9392 - val_loss: 0.1634 - learning_rate: 5.0000e-04
# Epoch 7/50
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.9650 - loss: 0.0995
# Epoch 7: val_loss improved from 0.16338 to 0.14513, saving model to ../models/best_model.keras
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 31s 76ms/step - accuracy: 0.9660 - loss: 0.0997 - val_accuracy: 0.9447 - val_loss: 0.1451 - learning_rate: 5.0000e-04
# Epoch 8/50
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.9647 - loss: 0.0891
# Epoch 8: val_loss did not improve from 0.14513
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 31s 76ms/step - accuracy: 0.9666 - loss: 0.0879 - val_accuracy: 0.9131 - val_loss: 0.2528 - learning_rate: 5.0000e-04
# Epoch 9/50
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.9703 - loss: 0.0790
# Epoch 9: val_loss did not improve from 0.14513
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 31s 76ms/step - accuracy: 0.9709 - loss: 0.0782 - val_accuracy: 0.8347 - val_loss: 0.6574 - learning_rate: 5.0000e-04
# Epoch 10/50
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.9693 - loss: 0.0882
# Epoch 10: val_loss did not improve from 0.14513
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 31s 76ms/step - accuracy: 0.9751 - loss: 0.0711 - val_accuracy: 0.7447 - val_loss: 1.1547 - learning_rate: 5.0000e-04
# Epoch 11/50
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.9776 - loss: 0.0672
# Epoch 11: val_loss did not improve from 0.14513
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 31s 76ms/step - accuracy: 0.9774 - loss: 0.0640 - val_accuracy: 0.8079 - val_loss: 0.6340 - learning_rate: 2.5000e-04
# Epoch 12/50
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9783 - loss: 0.0573
# Epoch 12: val_loss did not improve from 0.14513
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 31s 76ms/step - accuracy: 0.9792 - loss: 0.0575 - val_accuracy: 0.9471 - val_loss: 0.1714 - learning_rate: 2.5000e-04
# Epoch 13/50
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.9795 - loss: 0.0530
# Epoch 13: val_loss improved from 0.14513 to 0.13941, saving model to ../models/best_model.keras
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 31s 76ms/step - accuracy: 0.9802 - loss: 0.0554 - val_accuracy: 0.9398 - val_loss: 0.1394 - learning_rate: 2.5000e-04
# Epoch 14/50
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.9807 - loss: 0.0510
# Epoch 14: val_loss did not improve from 0.13941
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 31s 76ms/step - accuracy: 0.9790 - loss: 0.0554 - val_accuracy: 0.9210 - val_loss: 0.1921 - learning_rate: 2.5000e-04
# Epoch 15/50
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9808 - loss: 0.0611
# Epoch 15: val_loss did not improve from 0.13941
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 31s 76ms/step - accuracy: 0.9821 - loss: 0.0515 - val_accuracy: 0.9258 - val_loss: 0.1711 - learning_rate: 2.5000e-04
# Epoch 16/50
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9825 - loss: 0.0483
# Epoch 16: val_loss improved from 0.13941 to 0.05660, saving model to ../models/best_model.keras
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 31s 77ms/step - accuracy: 0.9805 - loss: 0.0561 - val_accuracy: 0.9793 - val_loss: 0.0566 - learning_rate: 2.5000e-04
# Epoch 17/50
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9835 - loss: 0.0537
# Epoch 17: val_loss did not improve from 0.05660
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 31s 76ms/step - accuracy: 0.9836 - loss: 0.0528 - val_accuracy: 0.9398 - val_loss: 0.1858 - learning_rate: 2.5000e-04
# Epoch 18/50
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.9827 - loss: 0.0474
# Epoch 18: val_loss improved from 0.05660 to 0.05220, saving model to ../models/best_model.keras
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 31s 76ms/step - accuracy: 0.9832 - loss: 0.0482 - val_accuracy: 0.9818 - val_loss: 0.0522 - learning_rate: 2.5000e-04
# Epoch 19/50
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9861 - loss: 0.0389
# Epoch 19: val_loss improved from 0.05220 to 0.04787, saving model to ../models/best_model.keras
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 31s 76ms/step - accuracy: 0.9837 - loss: 0.0442 - val_accuracy: 0.9836 - val_loss: 0.0479 - learning_rate: 2.5000e-04
# Epoch 20/50
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9846 - loss: 0.0413
# Epoch 20: val_loss did not improve from 0.04787
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 31s 76ms/step - accuracy: 0.9833 - loss: 0.0486 - val_accuracy: 0.9666 - val_loss: 0.0856 - learning_rate: 2.5000e-04
# Epoch 21/50
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9867 - loss: 0.0425
# Epoch 21: val_loss did not improve from 0.04787
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 31s 76ms/step - accuracy: 0.9859 - loss: 0.0420 - val_accuracy: 0.8845 - val_loss: 0.3509 - learning_rate: 2.5000e-04
# Epoch 22/50
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9848 - loss: 0.0426
# Epoch 22: val_loss did not improve from 0.04787
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 31s 76ms/step - accuracy: 0.9859 - loss: 0.0420 - val_accuracy: 0.9793 - val_loss: 0.0551 - learning_rate: 2.5000e-04
# Epoch 23/50
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.9899 - loss: 0.0324
# Epoch 23: val_loss did not improve from 0.04787
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 31s 76ms/step - accuracy: 0.9887 - loss: 0.0321 - val_accuracy: 0.9556 - val_loss: 0.1144 - learning_rate: 1.2500e-04
# Epoch 24/50
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.9893 - loss: 0.0323
# Epoch 24: val_loss improved from 0.04787 to 0.04061, saving model to ../models/best_model.keras
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 31s 76ms/step - accuracy: 0.9878 - loss: 0.0355 - val_accuracy: 0.9866 - val_loss: 0.0406 - learning_rate: 1.2500e-04
# Epoch 25/50
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9895 - loss: 0.0314
# Epoch 25: val_loss did not improve from 0.04061
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 31s 76ms/step - accuracy: 0.9891 - loss: 0.0308 - val_accuracy: 0.9860 - val_loss: 0.0432 - learning_rate: 1.2500e-04
# Epoch 26/50
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9879 - loss: 0.0367
# Epoch 26: val_loss did not improve from 0.04061
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 31s 76ms/step - accuracy: 0.9889 - loss: 0.0312 - val_accuracy: 0.9240 - val_loss: 0.2168 - learning_rate: 1.2500e-04
# Epoch 27/50
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9896 - loss: 0.0296
# Epoch 27: val_loss improved from 0.04061 to 0.03410, saving model to ../models/best_model.keras
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 31s 76ms/step - accuracy: 0.9893 - loss: 0.0280 - val_accuracy: 0.9878 - val_loss: 0.0341 - learning_rate: 1.2500e-04
# Epoch 28/50
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9921 - loss: 0.0210
# Epoch 28: val_loss improved from 0.03410 to 0.03280, saving model to ../models/best_model.keras
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 31s 76ms/step - accuracy: 0.9892 - loss: 0.0279 - val_accuracy: 0.9860 - val_loss: 0.0328 - learning_rate: 1.2500e-04
# Epoch 29/50
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9877 - loss: 0.0353
# Epoch 29: val_loss improved from 0.03280 to 0.02832, saving model to ../models/best_model.keras
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 31s 77ms/step - accuracy: 0.9885 - loss: 0.0325 - val_accuracy: 0.9878 - val_loss: 0.0283 - learning_rate: 1.2500e-04
# Epoch 30/50
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9912 - loss: 0.0270
# Epoch 30: val_loss did not improve from 0.02832
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 31s 77ms/step - accuracy: 0.9903 - loss: 0.0265 - val_accuracy: 0.9733 - val_loss: 0.0973 - learning_rate: 1.2500e-04
# Epoch 31/50
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9902 - loss: 0.0311
# Epoch 31: val_loss did not improve from 0.02832
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 31s 76ms/step - accuracy: 0.9915 - loss: 0.0292 - val_accuracy: 0.9836 - val_loss: 0.0402 - learning_rate: 1.2500e-04
# Epoch 32/50
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9883 - loss: 0.0337
# Epoch 32: val_loss did not improve from 0.02832
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 31s 76ms/step - accuracy: 0.9877 - loss: 0.0329 - val_accuracy: 0.9805 - val_loss: 0.0420 - learning_rate: 1.2500e-04
# Epoch 33/50
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9896 - loss: 0.0292
# Epoch 33: val_loss did not improve from 0.02832
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 31s 76ms/step - accuracy: 0.9900 - loss: 0.0268 - val_accuracy: 0.9860 - val_loss: 0.0328 - learning_rate: 6.2500e-05
# Epoch 34/50
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9917 - loss: 0.0250
# Epoch 34: val_loss improved from 0.02832 to 0.02427, saving model to ../models/best_model.keras
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 31s 77ms/step - accuracy: 0.9921 - loss: 0.0239 - val_accuracy: 0.9878 - val_loss: 0.0243 - learning_rate: 6.2500e-05
# Epoch 35/50
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9931 - loss: 0.0190
# Epoch 35: val_loss did not improve from 0.02427
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 31s 76ms/step - accuracy: 0.9930 - loss: 0.0217 - val_accuracy: 0.9818 - val_loss: 0.0446 - learning_rate: 6.2500e-05
# Epoch 36/50
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9920 - loss: 0.0246
# Epoch 36: val_loss did not improve from 0.02427
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 31s 76ms/step - accuracy: 0.9914 - loss: 0.0260 - val_accuracy: 0.9696 - val_loss: 0.0749 - learning_rate: 6.2500e-05
# Epoch 37/50
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9917 - loss: 0.0226
# Epoch 37: val_loss did not improve from 0.02427
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 31s 76ms/step - accuracy: 0.9928 - loss: 0.0209 - val_accuracy: 0.9866 - val_loss: 0.0273 - learning_rate: 6.2500e-05
# Epoch 38/50
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9902 - loss: 0.0251
# Epoch 38: val_loss did not improve from 0.02427
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 31s 76ms/step - accuracy: 0.9915 - loss: 0.0235 - val_accuracy: 0.9854 - val_loss: 0.0324 - learning_rate: 3.1250e-05
# Epoch 39/50
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9944 - loss: 0.0188
# Epoch 39: val_loss improved from 0.02427 to 0.02096, saving model to ../models/best_model.keras
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 31s 76ms/step - accuracy: 0.9944 - loss: 0.0190 - val_accuracy: 0.9927 - val_loss: 0.0210 - learning_rate: 3.1250e-05
# Epoch 40/50
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9918 - loss: 0.0204
# Epoch 40: val_loss did not improve from 0.02096
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 31s 76ms/step - accuracy: 0.9926 - loss: 0.0199 - val_accuracy: 0.9903 - val_loss: 0.0252 - learning_rate: 3.1250e-05
# Epoch 41/50
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9923 - loss: 0.0242
# Epoch 41: val_loss improved from 0.02096 to 0.01956, saving model to ../models/best_model.keras
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 31s 76ms/step - accuracy: 0.9928 - loss: 0.0216 - val_accuracy: 0.9933 - val_loss: 0.0196 - learning_rate: 3.1250e-05
# Epoch 42/50
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9947 - loss: 0.0170
# Epoch 42: val_loss improved from 0.01956 to 0.01777, saving model to ../models/best_model.keras
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 31s 77ms/step - accuracy: 0.9936 - loss: 0.0190 - val_accuracy: 0.9939 - val_loss: 0.0178 - learning_rate: 3.1250e-05
# Epoch 43/50
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9946 - loss: 0.0195
# Epoch 43: val_loss did not improve from 0.01777
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 31s 77ms/step - accuracy: 0.9937 - loss: 0.0198 - val_accuracy: 0.9939 - val_loss: 0.0210 - learning_rate: 3.1250e-05
# Epoch 44/50
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9941 - loss: 0.0182
# Epoch 44: val_loss did not improve from 0.01777
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 31s 76ms/step - accuracy: 0.9933 - loss: 0.0211 - val_accuracy: 0.9848 - val_loss: 0.0353 - learning_rate: 3.1250e-05
# Epoch 45/50
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9931 - loss: 0.0207
# Epoch 45: val_loss did not improve from 0.01777
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 31s 77ms/step - accuracy: 0.9933 - loss: 0.0231 - val_accuracy: 0.9921 - val_loss: 0.0252 - learning_rate: 3.1250e-05
# Epoch 46/50
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9920 - loss: 0.0250
# Epoch 46: val_loss did not improve from 0.01777
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 31s 76ms/step - accuracy: 0.9923 - loss: 0.0220 - val_accuracy: 0.9866 - val_loss: 0.0274 - learning_rate: 1.5625e-05
# Epoch 47/50
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9918 - loss: 0.0210
# Epoch 47: val_loss did not improve from 0.01777
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 31s 76ms/step - accuracy: 0.9925 - loss: 0.0200 - val_accuracy: 0.9933 - val_loss: 0.0201 - learning_rate: 1.5625e-05
# Epoch 48/50
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9943 - loss: 0.0177
# Epoch 48: val_loss did not improve from 0.01777
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 31s 76ms/step - accuracy: 0.9933 - loss: 0.0192 - val_accuracy: 0.9921 - val_loss: 0.0184 - learning_rate: 1.5625e-05

# %%
scores = model.evaluate(test_ds, verbose=1)
print("Test loss:", scores[0], "Test accuracy:", scores[1])
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9078 - loss: nan
# Test loss: nan Test accuracy: 0.9077669978141785

# %%
epochs_ran = len(history.history['loss'])
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.plot(range(1, epochs_ran+1), history.history['accuracy'], label='Train acc')
plt.plot(range(1, epochs_ran+1), history.history['val_accuracy'], label='Val acc')
plt.xlabel('Epoch'); plt.ylabel('Accuracy'); plt.legend(); plt.title('Accuracy')

plt.subplot(1,2,2)
plt.plot(range(1, epochs_ran+1), history.history['loss'], label='Train loss')
plt.plot(range(1, epochs_ran+1), history.history['val_loss'], label='Val loss')
plt.xlabel('Epoch'); plt.ylabel('Loss'); plt.legend(); plt.title('Loss')
plt.show()

# %%
def predict_image(model, image_tensor):
    img = tf.cast(image_tensor, tf.float32)
    img = tf.image.resize(img, IMAGE_SIZE)
    img = tf.expand_dims(img, 0)  # batch of 1
    preds = model.predict(img)
    idx = int(np.argmax(preds[0]))
    return class_names[idx], float(np.max(preds[0]) * 100.0)

# %%
plt.figure(figsize=(12,12))
for images, labels in test_ds.take(1):
    for i in range(min(9, images.shape[0])):
        ax = plt.subplot(3,3,i+1)
        img = images[i].numpy().astype('uint8')
        actual = class_names[int(labels[i])]
        pred_name, conf = predict_image(model, img)
        plt.imshow(img)
        plt.title(f"Actual: {actual}\nPred: {pred_name} ({conf:.1f}%)")
        plt.axis('off')
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2025-11-03 22:34:45.303687: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
# def safe_save_model(m, out_dir="../models"):
#     os.makedirs(out_dir, exist_ok=True)
#     existing = [d for d in os.listdir(out_dir) if os.path.isdir(os.path.join(out_dir, d))]
#     version = (max([int(v) for v in existing if v.isdigit()] + [0]) + 1)
#     save_path = os.path.join(out_dir, f"{version}.keras")
#     m.save(save_path)
#     print("✅ Saved model to", save_path)

# safe_save_model(model, checkpoint_dir)

# %%
def safe_save_model(model, out_dir="../models"):
    """
    Save a Keras model to `out_dir` with an incrementing version number.
    Example: 1.keras, 2.keras, 3.keras, ...
    """
    os.makedirs(out_dir, exist_ok=True)

    # Get all existing .keras files
    existing_files = [
        f for f in os.listdir(out_dir)
        if f.endswith(".keras") and f[:-6].isdigit()
    ]

    # Determine next version number
    if existing_files:
        versions = [int(f[:-6]) for f in existing_files]
        next_version = max(versions) + 1
    else:
        next_version = 1

    # Construct save path
    save_path = os.path.join(out_dir, f"{next_version}.keras")

    # Save the model
    model.save(save_path)
    print(f"✅ Saved model as: {save_path}")

    return save_path

safe_save_model(model)
# Out:
# ✅ Saved model as: ../models/2.keras
# '../models/2.keras'
