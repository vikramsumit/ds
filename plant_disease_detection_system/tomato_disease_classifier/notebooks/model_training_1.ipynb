# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers, models, callbacks
# Out:
# 2025-11-04 00:29:30.609375: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-04 00:29:30.849759: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-04 00:29:31.816030: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        for g in gpus:
            tf.config.experimental.set_memory_growth(g, True)
        print("Enabled memory growth for GPUs")
    except Exception as e:
        print("Could not set memory growth:", e)
# Out:
# Enabled memory growth for GPUs

# %%
BASE_DIR = "/home/amit/code_only/code/new/tomato_disease_classifier/data"
IMAGE_SIZE = (256, 256)
BATCH_SIZE = 5
CHANNELS = 3
NUM_CLASSES = 6
EPOCHS = 50
AUTOTUNE = tf.data.AUTOTUNE

# %%
train_dir = os.path.join(BASE_DIR, "Train")
val_dir   = os.path.join(BASE_DIR, "Val")
test_dir  = os.path.join(BASE_DIR, "Test")

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    train_dir,
    labels="inferred",
    label_mode="int",
    image_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    shuffle=True,
    seed=123
)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    val_dir,
    labels="inferred",
    label_mode="int",
    image_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    shuffle=True,
    seed=123
)

test_ds = tf.keras.preprocessing.image_dataset_from_directory(
    test_dir,
    labels="inferred",
    label_mode="int",
    image_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    shuffle=False
)

class_names = train_ds.class_names
print("Classes:", class_names)
# Out:
# Found 11108 files belonging to 6 classes.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1762196374.198040   76990 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 6292 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.9
# Found 2495 files belonging to 6 classes.
# Found 293 files belonging to 7 classes.
# Classes: ['Bacterial Spot', 'Early Blight', 'Healthy', 'Late Blight', 'Septoria Leaf Spot', 'Yellow Leaf Curl Virus']

# %%
train_ds = train_ds.shuffle(buffer_size=2000).prefetch(buffer_size=1)
val_ds   = val_ds.prefetch(buffer_size=1)
test_ds  = test_ds.prefetch(buffer_size=1)

# %%
AUTOTUNE = tf.data.AUTOTUNE
def augment(x, y):
    return x, y

# %%
input_shape = IMAGE_SIZE + (CHANNELS,)

augmentation = tf.keras.Sequential([
    layers.RandomFlip("horizontal_and_vertical"),
    layers.RandomRotation(0.10),
    layers.RandomZoom(0.1),
    layers.RandomContrast(0.1),
], name="augmentation")

model = models.Sequential([
    layers.Input(shape=input_shape),
    augmentation,
    layers.Rescaling(1./255),

    layers.Conv2D(32, 3, activation='relu', padding='same'),
    layers.BatchNormalization(),
    layers.MaxPooling2D(2),

    layers.Conv2D(64, 3, activation='relu', padding='same'),
    layers.BatchNormalization(),
    layers.MaxPooling2D(2),

    layers.Conv2D(128, 3, activation='relu', padding='same'),
    layers.BatchNormalization(),
    layers.MaxPooling2D(2),

    layers.Conv2D(128, 3, activation='relu', padding='same'),
    layers.BatchNormalization(),
    layers.MaxPooling2D(2),

    layers.GlobalAveragePooling2D(),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(NUM_CLASSES, activation='softmax')
], name="apple_disease_cnn")

model.compile(
    optimizer=tf.keras.optimizers.Adam(),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
    metrics=['accuracy']
)

model.summary()
# Out:
# Model: "apple_disease_cnn"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ augmentation (Sequential)       │ (None, 256, 256, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ rescaling (Rescaling)           │ (None, 256, 256, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 256, 256, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 256, 256, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 128, 128, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 128, 128, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 128, 128, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 64, 64, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 64, 64, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 64, 64, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 32, 32, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 32, 32, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 32, 32, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 16, 16, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 128)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 6)              │           774 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 259,526 (1013.77 KB)
#  Trainable params: 258,822 (1011.02 KB)
#  Non-trainable params: 704 (2.75 KB)

# %%
checkpoint_dir = "../models"
os.makedirs(checkpoint_dir, exist_ok=True)
checkpoint_path = os.path.join(checkpoint_dir, "best_model.keras")

cb = [
    callbacks.EarlyStopping(monitor='val_loss', patience=6, restore_best_weights=True),
    callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-6),
    callbacks.ModelCheckpoint(checkpoint_path, monitor='val_loss', save_best_only=True, verbose=1)
]

# %%
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS,
    callbacks=cb,
    verbose=1
)
# Out:
# Epoch 1/50
# 2025-11-04 00:29:42.932924: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:473] Loaded cuDNN version 91400
# 2220/2222 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5926 - loss: 1.0988
# Epoch 1: val_loss improved from None to 1.73472, saving model to ../models/best_model.keras
# 2222/2222 ━━━━━━━━━━━━━━━━━━━━ 51s 21ms/step - accuracy: 0.6701 - loss: 0.8990 - val_accuracy: 0.4709 - val_loss: 1.7347 - learning_rate: 0.0010
# Epoch 2/50
# 2222/2222 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7562 - loss: 0.6696
# Epoch 2: val_loss improved from 1.73472 to 1.62320, saving model to ../models/best_model.keras
# 2222/2222 ━━━━━━━━━━━━━━━━━━━━ 46s 20ms/step - accuracy: 0.7681 - loss: 0.6462 - val_accuracy: 0.6473 - val_loss: 1.6232 - learning_rate: 0.0010
# Epoch 3/50
# 2221/2222 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8110 - loss: 0.5393
# Epoch 3: val_loss improved from 1.62320 to 0.85426, saving model to ../models/best_model.keras
# 2222/2222 ━━━━━━━━━━━━━━━━━━━━ 46s 21ms/step - accuracy: 0.8145 - loss: 0.5248 - val_accuracy: 0.7423 - val_loss: 0.8543 - learning_rate: 0.0010
# Epoch 4/50
# 2222/2222 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8218 - loss: 0.4893
# Epoch 4: val_loss improved from 0.85426 to 0.61490, saving model to ../models/best_model.keras
# 2222/2222 ━━━━━━━━━━━━━━━━━━━━ 46s 21ms/step - accuracy: 0.8338 - loss: 0.4684 - val_accuracy: 0.8240 - val_loss: 0.6149 - learning_rate: 0.0010
# Epoch 5/50
# 2222/2222 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8573 - loss: 0.3998
# Epoch 5: val_loss improved from 0.61490 to 0.40198, saving model to ../models/best_model.keras
# 2222/2222 ━━━━━━━━━━━━━━━━━━━━ 46s 21ms/step - accuracy: 0.8633 - loss: 0.3908 - val_accuracy: 0.8986 - val_loss: 0.4020 - learning_rate: 0.0010
# Epoch 6/50
# 2222/2222 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8757 - loss: 0.3652
# Epoch 6: val_loss did not improve from 0.40198
# 2222/2222 ━━━━━━━━━━━━━━━━━━━━ 46s 21ms/step - accuracy: 0.8797 - loss: 0.3499 - val_accuracy: 0.8525 - val_loss: 0.4927 - learning_rate: 0.0010
# Epoch 7/50
# 2221/2222 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8907 - loss: 0.3182
# Epoch 7: val_loss did not improve from 0.40198
# 2222/2222 ━━━━━━━━━━━━━━━━━━━━ 46s 21ms/step - accuracy: 0.8936 - loss: 0.3172 - val_accuracy: 0.4850 - val_loss: 3.7150 - learning_rate: 0.0010
# Epoch 8/50
# 2222/2222 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9011 - loss: 0.2803
# Epoch 8: val_loss did not improve from 0.40198
# 2222/2222 ━━━━━━━━━━━━━━━━━━━━ 46s 21ms/step - accuracy: 0.9006 - loss: 0.2871 - val_accuracy: 0.6762 - val_loss: 1.7105 - learning_rate: 0.0010
# Epoch 9/50
# 2221/2222 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9274 - loss: 0.2202
# Epoch 9: val_loss did not improve from 0.40198
# 2222/2222 ━━━━━━━━━━━━━━━━━━━━ 46s 21ms/step - accuracy: 0.9301 - loss: 0.2105 - val_accuracy: 0.7603 - val_loss: 1.0922 - learning_rate: 5.0000e-04
# Epoch 10/50
# 2221/2222 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9305 - loss: 0.2019
# Epoch 10: val_loss improved from 0.40198 to 0.15076, saving model to ../models/best_model.keras
# 2222/2222 ━━━━━━━━━━━━━━━━━━━━ 46s 21ms/step - accuracy: 0.9308 - loss: 0.1981 - val_accuracy: 0.9519 - val_loss: 0.1508 - learning_rate: 5.0000e-04
# Epoch 11/50
# 2222/2222 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9333 - loss: 0.1979
# Epoch 11: val_loss did not improve from 0.15076
# 2222/2222 ━━━━━━━━━━━━━━━━━━━━ 46s 21ms/step - accuracy: 0.9341 - loss: 0.1999 - val_accuracy: 0.9263 - val_loss: 0.2309 - learning_rate: 5.0000e-04
# Epoch 12/50
# 2221/2222 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9381 - loss: 0.1788
# Epoch 12: val_loss did not improve from 0.15076
# 2222/2222 ━━━━━━━━━━━━━━━━━━━━ 46s 21ms/step - accuracy: 0.9406 - loss: 0.1736 - val_accuracy: 0.7940 - val_loss: 0.9503 - learning_rate: 5.0000e-04
# Epoch 13/50
# 2221/2222 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9447 - loss: 0.1592
# Epoch 13: val_loss did not improve from 0.15076
# 2222/2222 ━━━━━━━━━━━━━━━━━━━━ 46s 21ms/step - accuracy: 0.9448 - loss: 0.1601 - val_accuracy: 0.9575 - val_loss: 0.1515 - learning_rate: 5.0000e-04
# Epoch 14/50
# 2221/2222 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9493 - loss: 0.1511
# Epoch 14: val_loss did not improve from 0.15076
# 2222/2222 ━━━━━━━━━━━━━━━━━━━━ 46s 21ms/step - accuracy: 0.9530 - loss: 0.1395 - val_accuracy: 0.9275 - val_loss: 0.2746 - learning_rate: 2.5000e-04
# Epoch 15/50
# 2221/2222 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9603 - loss: 0.1204
# Epoch 15: val_loss improved from 0.15076 to 0.09525, saving model to ../models/best_model.keras
# 2222/2222 ━━━━━━━━━━━━━━━━━━━━ 46s 21ms/step - accuracy: 0.9583 - loss: 0.1282 - val_accuracy: 0.9739 - val_loss: 0.0952 - learning_rate: 2.5000e-04
# Epoch 16/50
# 2221/2222 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9620 - loss: 0.1203
# Epoch 16: val_loss did not improve from 0.09525
# 2222/2222 ━━━━━━━━━━━━━━━━━━━━ 46s 21ms/step - accuracy: 0.9592 - loss: 0.1242 - val_accuracy: 0.9627 - val_loss: 0.1311 - learning_rate: 2.5000e-04
# Epoch 17/50
# 2221/2222 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9630 - loss: 0.1072
# Epoch 17: val_loss did not improve from 0.09525
# 2222/2222 ━━━━━━━━━━━━━━━━━━━━ 46s 21ms/step - accuracy: 0.9605 - loss: 0.1151 - val_accuracy: 0.8870 - val_loss: 0.7579 - learning_rate: 2.5000e-04
# Epoch 18/50
# 2221/2222 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9607 - loss: 0.1264
# Epoch 18: val_loss did not improve from 0.09525
# 2222/2222 ━━━━━━━━━━━━━━━━━━━━ 46s 21ms/step - accuracy: 0.9600 - loss: 0.1193 - val_accuracy: 0.9495 - val_loss: 0.2228 - learning_rate: 2.5000e-04
# Epoch 19/50
# 2221/2222 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9612 - loss: 0.1122
# Epoch 19: val_loss improved from 0.09525 to 0.09130, saving model to ../models/best_model.keras
# 2222/2222 ━━━━━━━━━━━━━━━━━━━━ 46s 21ms/step - accuracy: 0.9644 - loss: 0.1046 - val_accuracy: 0.9784 - val_loss: 0.0913 - learning_rate: 1.2500e-04
# Epoch 20/50
# 2221/2222 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9675 - loss: 0.0920
# Epoch 20: val_loss did not improve from 0.09130
# 2222/2222 ━━━━━━━━━━━━━━━━━━━━ 46s 21ms/step - accuracy: 0.9667 - loss: 0.0953 - val_accuracy: 0.9655 - val_loss: 0.1267 - learning_rate: 1.2500e-04
# Epoch 21/50
# 2221/2222 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9671 - loss: 0.0975
# Epoch 21: val_loss did not improve from 0.09130
# 2222/2222 ━━━━━━━━━━━━━━━━━━━━ 46s 21ms/step - accuracy: 0.9672 - loss: 0.0948 - val_accuracy: 0.9695 - val_loss: 0.1233 - learning_rate: 1.2500e-04
# Epoch 22/50
# 2221/2222 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9710 - loss: 0.0881
# Epoch 22: val_loss did not improve from 0.09130
# 2222/2222 ━━━━━━━━━━━━━━━━━━━━ 46s 21ms/step - accuracy: 0.9697 - loss: 0.0859 - val_accuracy: 0.9399 - val_loss: 0.2129 - learning_rate: 1.2500e-04
# Epoch 23/50
# 2221/2222 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9680 - loss: 0.0914
# Epoch 23: val_loss improved from 0.09130 to 0.08797, saving model to ../models/best_model.keras
# 2222/2222 ━━━━━━━━━━━━━━━━━━━━ 46s 21ms/step - accuracy: 0.9714 - loss: 0.0848 - val_accuracy: 0.9743 - val_loss: 0.0880 - learning_rate: 6.2500e-05
# Epoch 24/50
# 2221/2222 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9747 - loss: 0.0780
# Epoch 24: val_loss did not improve from 0.08797
# 2222/2222 ━━━━━━━━━━━━━━━━━━━━ 46s 21ms/step - accuracy: 0.9727 - loss: 0.0800 - val_accuracy: 0.9703 - val_loss: 0.1131 - learning_rate: 6.2500e-05
# Epoch 25/50
# 2221/2222 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9730 - loss: 0.0833
# Epoch 25: val_loss did not improve from 0.08797
# 2222/2222 ━━━━━━━━━━━━━━━━━━━━ 46s 21ms/step - accuracy: 0.9731 - loss: 0.0789 - val_accuracy: 0.9727 - val_loss: 0.0906 - learning_rate: 6.2500e-05
# Epoch 26/50
# 2221/2222 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9731 - loss: 0.0816
# Epoch 26: val_loss did not improve from 0.08797
# 2222/2222 ━━━━━━━━━━━━━━━━━━━━ 46s 21ms/step - accuracy: 0.9747 - loss: 0.0773 - val_accuracy: 0.9743 - val_loss: 0.1058 - learning_rate: 6.2500e-05
# Epoch 27/50
# 2221/2222 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9726 - loss: 0.0806
# Epoch 27: val_loss did not improve from 0.08797
# 2222/2222 ━━━━━━━━━━━━━━━━━━━━ 46s 21ms/step - accuracy: 0.9747 - loss: 0.0733 - val_accuracy: 0.9727 - val_loss: 0.0976 - learning_rate: 3.1250e-05
# Epoch 28/50
# 2221/2222 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9741 - loss: 0.0800
# Epoch 28: val_loss did not improve from 0.08797
# 2222/2222 ━━━━━━━━━━━━━━━━━━━━ 46s 21ms/step - accuracy: 0.9750 - loss: 0.0737 - val_accuracy: 0.9735 - val_loss: 0.0944 - learning_rate: 3.1250e-05
# Epoch 29/50
# 2221/2222 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9749 - loss: 0.0704
# Epoch 29: val_loss did not improve from 0.08797
# 2222/2222 ━━━━━━━━━━━━━━━━━━━━ 46s 21ms/step - accuracy: 0.9752 - loss: 0.0735 - val_accuracy: 0.9687 - val_loss: 0.1171 - learning_rate: 3.1250e-05

# %%
scores = model.evaluate(test_ds, verbose=1)
print("Test loss:", scores[0], "Test accuracy:", scores[1])
# Out:
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6177 - loss: nan
# Test loss: nan Test accuracy: 0.61774742603302

# %%
epochs_ran = len(history.history['loss'])
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.plot(range(1, epochs_ran+1), history.history['accuracy'], label='Train acc')
plt.plot(range(1, epochs_ran+1), history.history['val_accuracy'], label='Val acc')
plt.xlabel('Epoch'); plt.ylabel('Accuracy'); plt.legend(); plt.title('Accuracy')

plt.subplot(1,2,2)
plt.plot(range(1, epochs_ran+1), history.history['loss'], label='Train loss')
plt.plot(range(1, epochs_ran+1), history.history['val_loss'], label='Val loss')
plt.xlabel('Epoch'); plt.ylabel('Loss'); plt.legend(); plt.title('Loss')
plt.show()

# %%
def predict_image(model, image_tensor):
    img = tf.cast(image_tensor, tf.float32)
    img = tf.image.resize(img, IMAGE_SIZE)
    img = tf.expand_dims(img, 0)  # batch of 1
    preds = model.predict(img)
    idx = int(np.argmax(preds[0]))
    return class_names[idx], float(np.max(preds[0]) * 100.0)

# %%
plt.figure(figsize=(12,12))
for images, labels in test_ds.take(1):
    for i in range(min(9, images.shape[0])):
        ax = plt.subplot(3,3,i+1)
        img = images[i].numpy().astype('uint8')
        actual = class_names[int(labels[i])]
        pred_name, conf = predict_image(model, img)
        plt.imshow(img)
        plt.title(f"Actual: {actual}\nPred: {pred_name} ({conf:.1f}%)")
        plt.axis('off')
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2025-11-04 00:52:34.520770: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
# def safe_save_model(m, out_dir="../models"):
#     os.makedirs(out_dir, exist_ok=True)
#     existing = [d for d in os.listdir(out_dir) if os.path.isdir(os.path.join(out_dir, d))]
#     version = (max([int(v) for v in existing if v.isdigit()] + [0]) + 1)
#     save_path = os.path.join(out_dir, f"{version}.keras")
#     m.save(save_path)
#     print("✅ Saved model to", save_path)

# safe_save_model(model, checkpoint_dir)

# %%
def safe_save_model(model, out_dir="../models"):
    """
    Save a Keras model to `out_dir` with an incrementing version number.
    Example: 1.keras, 2.keras, 3.keras, ...
    """
    os.makedirs(out_dir, exist_ok=True)

    # Get all existing .keras files
    existing_files = [
        f for f in os.listdir(out_dir)
        if f.endswith(".keras") and f[:-6].isdigit()
    ]

    # Determine next version number
    if existing_files:
        versions = [int(f[:-6]) for f in existing_files]
        next_version = max(versions) + 1
    else:
        next_version = 1

    # Construct save path
    save_path = os.path.join(out_dir, f"{next_version}.keras")

    # Save the model
    model.save(save_path)
    print(f"✅ Saved model as: {save_path}")

    return save_path

safe_save_model(model)
# Out:
# ✅ Saved model as: ../models/2.keras
# '../models/2.keras'
