# %%
import tensorflow as tf
import matplotlib.pyplot as plt
# export TF_ENABLE_ONEDNN_OPTS=0
# Out:
# 2026-02-16 13:23:59.619850: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-02-16 13:23:59.716781: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-02-16 13:24:02.117599: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 27s 2us/step

# %%
# check the shape and labels

print("Training data shape:", x_train.shape)
print("Training labels shape:", y_train.shape)
# Out:
# Training data shape: (60000, 28, 28)
# Training labels shape: (60000,)

# %%
print("Training data shape:", x_test.shape)
print("Training labels shape:", y_test.shape)
# Out:
# Training data shape: (10000, 28, 28)
# Training labels shape: (10000,)

# %%
# Plot first 20 images with their labels
plt.figure(figsize=(10, 2))
for i in range(20):
    plt.subplot(2, 10, i + 1) # 2 row 10 column
    plt.imshow(x_train[i], cmap="gray")
    plt.axis("off")
    plt.title(str(y_train[i]))
plt.tight_layout()
plt.show()
